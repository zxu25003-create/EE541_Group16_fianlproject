# %%
# import sys
# sys.path.append('/kaggle/input/project-541/project')

import os
import random
from typing import List

import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt

import torch
import torchaudio
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models

from augment import WaveformAugment

# %%
# configurations

DATA_DIR = "./data/UrbanSound8K" # dataset path
MODEL_DIR = "./model/model-b" # store trained model and figure (path)
os.makedirs(MODEL_DIR, exist_ok=True)

SAMPLE_RATE = 22050 # sample rate
CLIP_DURATION = 4.0 # length of clip
N_CLASSES = 10

N_MELS = 128
FMIN = 0
FMAX = SAMPLE_RATE // 2

BATCH_SIZE = 128 # batch size
NUM_EPOCHS = 10 # epoch

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", DEVICE)


def set_seed(seed: int = 38):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    
set_seed(38)
# Out:
# Using device: cuda

# %%
# Dataset construct

class UrbanSound8KWaveDataset(Dataset):
    def __init__(
        self,
        data_dir: str,
        folds: List[int],
        sample_rate: int = SAMPLE_RATE,
        duration: float = CLIP_DURATION,
        waveform_augment: WaveformAugment = None,
    ):
        super().__init__()
        self.data_dir = data_dir
        self.folds = folds if isinstance(folds, list) else [folds]
        self.sample_rate = sample_rate
        self.duration = duration
        self.n_samples = int(sample_rate * duration)
        self.waveform_augment = waveform_augment

        meta_path = os.path.join(data_dir, "metadata", "UrbanSound8K.csv")
        df = pd.read_csv(meta_path)
        self.df = df[df["fold"].isin(self.folds)].reset_index(drop=True)
        self.labels = self.df["classID"].astype(int).to_numpy()

    def __len__(self):
        return len(self.df)

    def _load_waveform(self, index: int) -> torch.Tensor:
        row = self.df.iloc[index]
        fold = row["fold"]
        filename = row["slice_file_name"]
        file_path = os.path.join(self.data_dir, "audio", f"fold{fold}", filename)

        # resample
        wav, sr = librosa.load(file_path, sr=self.sample_rate, mono=True)

        # pad / truncate to 4 seconds
        if len(wav) < self.n_samples:
            wav = np.pad(wav, (0, self.n_samples - len(wav)), mode="constant")
        elif len(wav) > self.n_samples:
            wav = wav[: self.n_samples]

        # normalization
        if np.std(wav) > 1e-6:
            wav = (wav - wav.mean()) / wav.std()

        wav = wav.astype(np.float32)
        return torch.from_numpy(wav).unsqueeze(0)  # [1, T]

    def __getitem__(self, index: int):
        label = int(self.labels[index])
        wav = self._load_waveform(index)

        # data augmentation (for train set)
        if self.waveform_augment is not None:
            wav = self.waveform_augment(wav)

        return wav, torch.tensor(label, dtype=torch.long) # return waveform [1, T] and label

# %%
# pretrained VGG-13-BN model (pretrained on imagenet1k)

def create_pretrained_vgg13(num_classes: int = N_CLASSES) -> nn.Module:
    try:
        vgg = models.vgg13_bn(weights=models.VGG13_BN_Weights.IMAGENET1K_V1)
    except AttributeError:
        vgg = models.vgg13_bn(pretrained=True)

    # change the last classifier to 10 classes
    in_features = vgg.classifier[-1].in_features
    vgg.classifier[-1] = nn.Linear(in_features, num_classes)

    return vgg

# %%
# mel transformation (change waveform to mel spectrogram)

mel_transform = torchaudio.transforms.MelSpectrogram(
    sample_rate=SAMPLE_RATE,
    n_fft=1024,
    hop_length=512,
    n_mels=N_MELS,
    f_min=FMIN,
    f_max=FMAX,
    power=2.0,
).to(DEVICE)

db_transform = torchaudio.transforms.AmplitudeToDB().to(DEVICE)


def waveform_batch_to_mel(x_wave: torch.Tensor) -> torch.Tensor:
    x_in = x_wave.squeeze(1)   # [B, T]

    # generate mel
    mel = mel_transform(x_in)
    mel_db = db_transform(mel)

    # normalization
    mean = mel_db.mean(dim=(1, 2), keepdim=True)
    std = mel_db.std(dim=(1, 2), keepdim=True)
    mel_db = (mel_db - mean) / (std + 1e-6)

    # add dimension for channel [B, 1, n_mels, frames]
    mel_db = mel_db.unsqueeze(1)

    # copy to 3 channels [B, 3, n_mels, frames]
    mel_db = mel_db.repeat(1, 3, 1, 1)

    return mel_db

# %%
# 3-stage Fine-tuning

def set_trainable_stage(model: nn.Module, stage: int):
    """
    stage 1: only train classifier
    stage 2: train the final conv block and classifier
    stage 3: train the whole model
    """
    # freeze all
    for p in model.parameters():
        p.requires_grad = False

    if stage == 1:
        # unfreeze classifier
        for p in model.classifier.parameters():
            p.requires_grad = True

    elif stage == 2:
        # unfreeze classifier + last conv block
        for p in model.classifier.parameters():
            p.requires_grad = True

        features = list(model.features.children())
        for layer in features[-6:]:
            for p in layer.parameters():
                p.requires_grad = True

    elif stage == 3:
        # freeze all
        for p in model.parameters():
            p.requires_grad = True

    else:
        raise ValueError(f"Unknown stage: {stage}")


def create_optimizer_for_stage(model: nn.Module, stage: int): # construct optimizer
    if stage == 1:
        lr = 1e-5
    elif stage == 2:
        lr = 5e-6
    elif stage == 3:
        lr = 1e-6
    else:
        raise ValueError(f"Unknown stage: {stage}")

    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.Adam(params, lr=lr, weight_decay=1e-4) # Adam, L2 regularization
    return optimizer, lr

def get_stage_for_epoch(epoch: int):
    """
    1-10  : stage 1
    11-12 : stage 2
    13-20: stage 3
    """
    if epoch <= 10:
        return 1
    elif epoch <= 12:
        return 2
    else:
        return 3

# %%
# Functions for train, validate and plot

def train_one_epoch(model, loader, criterion, optimizer, device): # train one epoch
    model.train()
    running_loss, correct, total = 0.0, 0, 0

    for x_wave, y in loader:
        x_wave = x_wave.to(device) # [B, 1, T]
        y = y.to(device)

        # change waveform to mel
        x = waveform_batch_to_mel(x_wave) # [B, 1, n_mels, frames]

        optimizer.zero_grad() # zero gradient
        logits = model(x) # forward
        loss = criterion(logits, y) # loss
        loss.backward() # backward
        optimizer.step() # update

        running_loss += loss.item() * x.size(0)
        _, preds = torch.max(logits, dim=1)
        correct += (preds == y).sum().item()
        total += y.size(0)

    return running_loss / total, correct / total


@torch.no_grad() # evaluate
def evaluate(model, loader, criterion, device):
    model.eval()
    running_loss, correct, total = 0.0, 0, 0

    for x_wave, y in loader:
        x_wave = x_wave.to(device)
        y = y.to(device)

        x = waveform_batch_to_mel(x_wave)

        logits = model(x)
        loss = criterion(logits, y)

        running_loss += loss.item() * x.size(0)
        _, preds = torch.max(logits, dim=1)
        correct += (preds == y).sum().item()
        total += y.size(0)

    return running_loss / total, correct / total


def plot_learning_curve(history, fold_id: int, save_dir: str = MODEL_DIR): # plot
    epochs = range(1, len(history["train_loss"]) + 1)

    plt.figure(figsize=(10, 4))

    # loss
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history["train_loss"], label="Train Loss")
    plt.plot(epochs, history["val_loss"], label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"b - Fold {fold_id} - Loss")
    plt.legend()

    # accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history["train_acc"], label="Train Acc")
    plt.plot(epochs, history["val_acc"], label="Val Acc")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title(f"b - Fold {fold_id} - Accuracy")
    plt.legend()

    plt.tight_layout()
    save_path = os.path.join(save_dir, f"vgg13_b_fold{fold_id}_curve.png")
    plt.savefig(save_path, dpi=150)
    plt.close()
    print(f"Saved learning curve to: {save_path}")

# %%
# 10-fold Cross-Validation train

all_folds = list(range(1, 11))

for test_fold in all_folds:
    print("=" * 80)
    print(f"Fold {test_fold} as TEST fold")
    print("=" * 80)

    # current fold as test set, remaining 9 folds as train set and val set
    trainval_folds = [f for f in all_folds if f != test_fold]

    # last fold of remaining 9 set as val set，remaining 8 folds as train set
    val_fold = trainval_folds[-1]
    train_folds = trainval_folds[:-1]

    print(f"Train folds: {train_folds}")
    print(f"Val fold:   {val_fold}")
    print(f"Test fold:  {test_fold}")

    # augmentation
    wave_aug = WaveformAugment(sample_rate=SAMPLE_RATE)

    train_dataset = UrbanSound8KWaveDataset(
        data_dir=DATA_DIR,
        folds=train_folds,
        sample_rate=SAMPLE_RATE,
        duration=CLIP_DURATION,
        waveform_augment=None, # don't do augmentation
    )

    val_dataset = UrbanSound8KWaveDataset(
        data_dir=DATA_DIR,
        folds=[val_fold],
        sample_rate=SAMPLE_RATE,
        duration=CLIP_DURATION,
        waveform_augment=None, # don't do augmentation
    )

    test_dataset = UrbanSound8KWaveDataset(
        data_dir=DATA_DIR,
        folds=[test_fold],
        sample_rate=SAMPLE_RATE,
        duration=CLIP_DURATION,
        waveform_augment=None, # don't do augmentation
    )

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              shuffle=True, num_workers=2)
    val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE,
                              shuffle=False, num_workers=2)
    test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE,
                              shuffle=False, num_workers=2)

    # creat model VGG-13
    model = create_pretrained_vgg13(num_classes=N_CLASSES).to(DEVICE)
    criterion = nn.CrossEntropyLoss()

    history = {
        "train_loss": [],
        "val_loss": [],
        "train_acc": [],
        "val_acc": [],
    }

    current_stage = None
    optimizer = None
    current_lr = None

    for epoch in range(1, NUM_EPOCHS + 1):
        stage = get_stage_for_epoch(epoch)
        if stage != current_stage:
            # reset requires_grad and optimizer when entering new stage
            current_stage = stage
            set_trainable_stage(model, stage)
            optimizer, current_lr = create_optimizer_for_stage(model, stage)
            print(f"\nSwitch to stage {stage} at epoch {epoch}, lr = {current_lr:g}")

        print(f"\n[Fold {test_fold}] Epoch {epoch}/{NUM_EPOCHS} (Stage {current_stage}, lr={current_lr:g})")

        train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, DEVICE) # train one epoch
        val_loss, val_acc = evaluate(model, val_loader, criterion, DEVICE) # evaluate on val set

        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["train_acc"].append(train_acc)
        history["val_acc"].append(val_acc)

        print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}")
        print(f"Val   Loss: {val_loss:.4f}, Val   Acc: {val_acc:.4f}")

    # plot learning curve
    plot_learning_curve(history, fold_id=test_fold, save_dir=MODEL_DIR)

    # test on test set after finishing training
    test_loss, test_acc = evaluate(model, test_loader, criterion, DEVICE)
    print(f"[Fold {test_fold}] Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}")

    # store the model
    model_path = os.path.join(MODEL_DIR, f"vgg13_b_fold{test_fold}.pth") #  fold i, means that it is used for test for this training
    torch.save(model.state_dict(), model_path)
    print(f"Saved model for fold {test_fold} to: {model_path}")
# Out:
# ================================================================================
# Fold 1 as TEST fold
# ================================================================================
# Train folds: [2, 3, 4, 5, 6, 7, 8, 9]
# Val fold:   10
# Test fold:  1
# Downloading: "https://download.pytorch.org/models/vgg13_bn-abd245e5.pth" to /root/.cache/torch/hub/checkpoints/vgg13_bn-abd245e5.pth
# 100%|██████████| 508M/508M [00:02<00:00, 255MB/s]
# Switch to stage 1 at epoch 1, lr = 1e-05
#
# [Fold 1] Epoch 1/10 (Stage 1, lr=1e-05)
# Train Loss: 2.0321, Train Acc: 0.2985
# Val   Loss: 1.6469, Val   Acc: 0.5579
#
# [Fold 1] Epoch 2/10 (Stage 1, lr=1e-05)
# Train Loss: 1.4052, Train Acc: 0.5689
# Val   Loss: 1.1612, Val   Acc: 0.6547
#
# [Fold 1] Epoch 3/10 (Stage 1, lr=1e-05)
# Train Loss: 1.0593, Train Acc: 0.6659
# Val   Loss: 0.9862, Val   Acc: 0.7025
#
# [Fold 1] Epoch 4/10 (Stage 1, lr=1e-05)
# Train Loss: 0.8675, Train Acc: 0.7257
# Val   Loss: 0.9060, Val   Acc: 0.7228
#
# [Fold 1] Epoch 5/10 (Stage 1, lr=1e-05)
# Train Loss: 0.7407, Train Acc: 0.7640
# Val   Loss: 0.8465, Val   Acc: 0.7360
#
# [Fold 1] Epoch 6/10 (Stage 1, lr=1e-05)
# Train Loss: 0.6563, Train Acc: 0.7888
# Val   Loss: 0.8307, Val   Acc: 0.7419
#
# [Fold 1] Epoch 7/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5667, Train Acc: 0.8218
# Val   Loss: 0.8186, Val   Acc: 0.7443
#
# [Fold 1] Epoch 8/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5172, Train Acc: 0.8345
# Val   Loss: 0.7993, Val   Acc: 0.7539
#
# [Fold 1] Epoch 9/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4687, Train Acc: 0.8520
# Val   Loss: 0.7914, Val   Acc: 0.7515
#
# [Fold 1] Epoch 10/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4219, Train Acc: 0.8666
# Val   Loss: 0.7863, Val   Acc: 0.7599
# Saved learning curve to: /kaggle/working/model-b/vgg13_b_fold1_curve.png
# [Fold 1] Test Loss: 0.8328, Test Acc: 0.7068
# Saved model for fold 1 to: /kaggle/working/model-b/vgg13_b_fold1.pth
# ================================================================================
# Fold 2 as TEST fold
# ================================================================================
# Train folds: [1, 3, 4, 5, 6, 7, 8, 9]
# Val fold:   10
# Test fold:  2
#
# Switch to stage 1 at epoch 1, lr = 1e-05
#
# [Fold 2] Epoch 1/10 (Stage 1, lr=1e-05)
# Train Loss: 2.0525, Train Acc: 0.2821
# Val   Loss: 1.6222, Val   Acc: 0.5854
#
# [Fold 2] Epoch 2/10 (Stage 1, lr=1e-05)
# Train Loss: 1.4220, Train Acc: 0.5573
# Val   Loss: 1.1249, Val   Acc: 0.6607
#
# [Fold 2] Epoch 3/10 (Stage 1, lr=1e-05)
# Train Loss: 1.0603, Train Acc: 0.6538
# Val   Loss: 0.9514, Val   Acc: 0.7073
#
# [Fold 2] Epoch 4/10 (Stage 1, lr=1e-05)
# Train Loss: 0.8725, Train Acc: 0.7226
# Val   Loss: 0.8581, Val   Acc: 0.7348
#
# [Fold 2] Epoch 5/10 (Stage 1, lr=1e-05)
# Train Loss: 0.7354, Train Acc: 0.7647
# Val   Loss: 0.8287, Val   Acc: 0.7419
#
# [Fold 2] Epoch 6/10 (Stage 1, lr=1e-05)
# Train Loss: 0.6425, Train Acc: 0.7986
# Val   Loss: 0.8111, Val   Acc: 0.7479
#
# [Fold 2] Epoch 7/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5802, Train Acc: 0.8188
# Val   Loss: 0.7944, Val   Acc: 0.7575
#
# [Fold 2] Epoch 8/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5087, Train Acc: 0.8440
# Val   Loss: 0.7830, Val   Acc: 0.7575
#
# [Fold 2] Epoch 9/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4672, Train Acc: 0.8533
# Val   Loss: 0.7685, Val   Acc: 0.7611
#
# [Fold 2] Epoch 10/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4142, Train Acc: 0.8760
# Val   Loss: 0.7673, Val   Acc: 0.7587
# Saved learning curve to: /kaggle/working/model-b/vgg13_b_fold2_curve.png
# [Fold 2] Test Loss: 0.9045, Test Acc: 0.7410
# Saved model for fold 2 to: /kaggle/working/model-b/vgg13_b_fold2.pth
# ================================================================================
# Fold 3 as TEST fold
# ================================================================================
# Train folds: [1, 2, 4, 5, 6, 7, 8, 9]
# Val fold:   10
# Test fold:  3
#
# Switch to stage 1 at epoch 1, lr = 1e-05
#
# [Fold 3] Epoch 1/10 (Stage 1, lr=1e-05)
# Train Loss: 2.0586, Train Acc: 0.2755
# Val   Loss: 1.6580, Val   Acc: 0.5556
#
# [Fold 3] Epoch 2/10 (Stage 1, lr=1e-05)
# Train Loss: 1.4238, Train Acc: 0.5527
# Val   Loss: 1.1650, Val   Acc: 0.6368
#
# [Fold 3] Epoch 3/10 (Stage 1, lr=1e-05)
# Train Loss: 1.0730, Train Acc: 0.6594
# Val   Loss: 0.9954, Val   Acc: 0.6798
#
# [Fold 3] Epoch 4/10 (Stage 1, lr=1e-05)
# Train Loss: 0.8840, Train Acc: 0.7211
# Val   Loss: 0.8931, Val   Acc: 0.7121
#
# [Fold 3] Epoch 5/10 (Stage 1, lr=1e-05)
# Train Loss: 0.7502, Train Acc: 0.7626
# Val   Loss: 0.8484, Val   Acc: 0.7121
#
# [Fold 3] Epoch 6/10 (Stage 1, lr=1e-05)
# Train Loss: 0.6542, Train Acc: 0.7948
# Val   Loss: 0.8144, Val   Acc: 0.7276
#
# [Fold 3] Epoch 7/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5859, Train Acc: 0.8154
# Val   Loss: 0.8157, Val   Acc: 0.7240
#
# [Fold 3] Epoch 8/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5248, Train Acc: 0.8353
# Val   Loss: 0.7834, Val   Acc: 0.7372
#
# [Fold 3] Epoch 9/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4701, Train Acc: 0.8554
# Val   Loss: 0.7876, Val   Acc: 0.7348
#
# [Fold 3] Epoch 10/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4318, Train Acc: 0.8702
# Val   Loss: 0.7782, Val   Acc: 0.7419
# Saved learning curve to: /kaggle/working/model-b/vgg13_b_fold3_curve.png
# [Fold 3] Test Loss: 0.7731, Test Acc: 0.7178
# Saved model for fold 3 to: /kaggle/working/model-b/vgg13_b_fold3.pth
# ================================================================================
# Fold 4 as TEST fold
# ================================================================================
# Train folds: [1, 2, 3, 5, 6, 7, 8, 9]
# Val fold:   10
# Test fold:  4
#
# Switch to stage 1 at epoch 1, lr = 1e-05
#
# [Fold 4] Epoch 1/10 (Stage 1, lr=1e-05)
# Train Loss: 2.0418, Train Acc: 0.2824
# Val   Loss: 1.6237, Val   Acc: 0.5579
#
# [Fold 4] Epoch 2/10 (Stage 1, lr=1e-05)
# Train Loss: 1.4107, Train Acc: 0.5557
# Val   Loss: 1.1344, Val   Acc: 0.6559
#
# [Fold 4] Epoch 3/10 (Stage 1, lr=1e-05)
# Train Loss: 1.0707, Train Acc: 0.6579
# Val   Loss: 0.9702, Val   Acc: 0.6906
#
# [Fold 4] Epoch 4/10 (Stage 1, lr=1e-05)
# Train Loss: 0.8783, Train Acc: 0.7234
# Val   Loss: 0.8890, Val   Acc: 0.7240
#
# [Fold 4] Epoch 5/10 (Stage 1, lr=1e-05)
# Train Loss: 0.7424, Train Acc: 0.7641
# Val   Loss: 0.8587, Val   Acc: 0.7348
#
# [Fold 4] Epoch 6/10 (Stage 1, lr=1e-05)
# Train Loss: 0.6699, Train Acc: 0.7857
# Val   Loss: 0.8098, Val   Acc: 0.7431
#
# [Fold 4] Epoch 7/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5827, Train Acc: 0.8133
# Val   Loss: 0.7960, Val   Acc: 0.7384
#
# [Fold 4] Epoch 8/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5215, Train Acc: 0.8374
# Val   Loss: 0.7910, Val   Acc: 0.7503
#
# [Fold 4] Epoch 9/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4767, Train Acc: 0.8507
# Val   Loss: 0.7801, Val   Acc: 0.7539
#
# [Fold 4] Epoch 10/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4327, Train Acc: 0.8657
# Val   Loss: 0.7759, Val   Acc: 0.7539
# Saved learning curve to: /kaggle/working/model-b/vgg13_b_fold4_curve.png
# [Fold 4] Test Loss: 0.7584, Test Acc: 0.7343
# Saved model for fold 4 to: /kaggle/working/model-b/vgg13_b_fold4.pth
# ================================================================================
# Fold 5 as TEST fold
# ================================================================================
# Train folds: [1, 2, 3, 4, 6, 7, 8, 9]
# Val fold:   10
# Test fold:  5
#
# Switch to stage 1 at epoch 1, lr = 1e-05
#
# [Fold 5] Epoch 1/10 (Stage 1, lr=1e-05)
# Train Loss: 2.0040, Train Acc: 0.3052
# Val   Loss: 1.5755, Val   Acc: 0.5974
#
# [Fold 5] Epoch 2/10 (Stage 1, lr=1e-05)
# Train Loss: 1.3796, Train Acc: 0.5611
# Val   Loss: 1.1509, Val   Acc: 0.6810
#
# [Fold 5] Epoch 3/10 (Stage 1, lr=1e-05)
# Train Loss: 1.0558, Train Acc: 0.6670
# Val   Loss: 0.9794, Val   Acc: 0.7133
#
# [Fold 5] Epoch 4/10 (Stage 1, lr=1e-05)
# Train Loss: 0.8797, Train Acc: 0.7245
# Val   Loss: 0.8865, Val   Acc: 0.7288
#
# [Fold 5] Epoch 5/10 (Stage 1, lr=1e-05)
# Train Loss: 0.7643, Train Acc: 0.7517
# Val   Loss: 0.8464, Val   Acc: 0.7336
#
# [Fold 5] Epoch 6/10 (Stage 1, lr=1e-05)
# Train Loss: 0.6723, Train Acc: 0.7899
# Val   Loss: 0.8125, Val   Acc: 0.7431
#
# [Fold 5] Epoch 7/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5900, Train Acc: 0.8187
# Val   Loss: 0.8043, Val   Acc: 0.7479
#
# [Fold 5] Epoch 8/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5309, Train Acc: 0.8362
# Val   Loss: 0.7921, Val   Acc: 0.7599
#
# [Fold 5] Epoch 9/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4665, Train Acc: 0.8569
# Val   Loss: 0.7808, Val   Acc: 0.7587
#
# [Fold 5] Epoch 10/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4367, Train Acc: 0.8691
# Val   Loss: 0.7631, Val   Acc: 0.7634
# Saved learning curve to: /kaggle/working/model-b/vgg13_b_fold5_curve.png
# [Fold 5] Test Loss: 0.7228, Test Acc: 0.7575
# Saved model for fold 5 to: /kaggle/working/model-b/vgg13_b_fold5.pth
# ================================================================================
# Fold 6 as TEST fold
# ================================================================================
# Train folds: [1, 2, 3, 4, 5, 7, 8, 9]
# Val fold:   10
# Test fold:  6
#
# Switch to stage 1 at epoch 1, lr = 1e-05
#
# [Fold 6] Epoch 1/10 (Stage 1, lr=1e-05)
# Train Loss: 2.0141, Train Acc: 0.3105
# Val   Loss: 1.5594, Val   Acc: 0.6057
#
# [Fold 6] Epoch 2/10 (Stage 1, lr=1e-05)
# Train Loss: 1.3808, Train Acc: 0.5754
# Val   Loss: 1.0760, Val   Acc: 0.6894
#
# [Fold 6] Epoch 3/10 (Stage 1, lr=1e-05)
# Train Loss: 1.0377, Train Acc: 0.6734
# Val   Loss: 0.8991, Val   Acc: 0.7240
#
# [Fold 6] Epoch 4/10 (Stage 1, lr=1e-05)
# Train Loss: 0.8626, Train Acc: 0.7234
# Val   Loss: 0.8472, Val   Acc: 0.7240
#
# [Fold 6] Epoch 5/10 (Stage 1, lr=1e-05)
# Train Loss: 0.7204, Train Acc: 0.7742
# Val   Loss: 0.7885, Val   Acc: 0.7431
#
# [Fold 6] Epoch 6/10 (Stage 1, lr=1e-05)
# Train Loss: 0.6298, Train Acc: 0.8049
# Val   Loss: 0.7726, Val   Acc: 0.7515
#
# [Fold 6] Epoch 7/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5763, Train Acc: 0.8174
# Val   Loss: 0.7406, Val   Acc: 0.7551
#
# [Fold 6] Epoch 8/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5053, Train Acc: 0.8426
# Val   Loss: 0.7397, Val   Acc: 0.7599
#
# [Fold 6] Epoch 9/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4515, Train Acc: 0.8626
# Val   Loss: 0.7424, Val   Acc: 0.7611
#
# [Fold 6] Epoch 10/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4184, Train Acc: 0.8706
# Val   Loss: 0.7226, Val   Acc: 0.7622
# Saved learning curve to: /kaggle/working/model-b/vgg13_b_fold6_curve.png
# [Fold 6] Test Loss: 1.1785, Test Acc: 0.6889
# Saved model for fold 6 to: /kaggle/working/model-b/vgg13_b_fold6.pth
# ================================================================================
# Fold 7 as TEST fold
# ================================================================================
# Train folds: [1, 2, 3, 4, 5, 6, 8, 9]
# Val fold:   10
# Test fold:  7
#
# Switch to stage 1 at epoch 1, lr = 1e-05
#
# [Fold 7] Epoch 1/10 (Stage 1, lr=1e-05)
# Train Loss: 2.0020, Train Acc: 0.3176
# Val   Loss: 1.5945, Val   Acc: 0.5460
#
# [Fold 7] Epoch 2/10 (Stage 1, lr=1e-05)
# Train Loss: 1.3858, Train Acc: 0.5636
# Val   Loss: 1.1363, Val   Acc: 0.6691
#
# [Fold 7] Epoch 3/10 (Stage 1, lr=1e-05)
# Train Loss: 1.0506, Train Acc: 0.6705
# Val   Loss: 0.9875, Val   Acc: 0.6834
#
# [Fold 7] Epoch 4/10 (Stage 1, lr=1e-05)
# Train Loss: 0.8577, Train Acc: 0.7301
# Val   Loss: 0.9039, Val   Acc: 0.7133
#
# [Fold 7] Epoch 5/10 (Stage 1, lr=1e-05)
# Train Loss: 0.7562, Train Acc: 0.7614
# Val   Loss: 0.8701, Val   Acc: 0.7228
#
# [Fold 7] Epoch 6/10 (Stage 1, lr=1e-05)
# Train Loss: 0.6573, Train Acc: 0.7921
# Val   Loss: 0.8243, Val   Acc: 0.7384
#
# [Fold 7] Epoch 7/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5860, Train Acc: 0.8159
# Val   Loss: 0.8052, Val   Acc: 0.7467
#
# [Fold 7] Epoch 8/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5360, Train Acc: 0.8326
# Val   Loss: 0.7923, Val   Acc: 0.7360
#
# [Fold 7] Epoch 9/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4733, Train Acc: 0.8572
# Val   Loss: 0.7968, Val   Acc: 0.7467
#
# [Fold 7] Epoch 10/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4348, Train Acc: 0.8737
# Val   Loss: 0.7860, Val   Acc: 0.7539
# Saved learning curve to: /kaggle/working/model-b/vgg13_b_fold7_curve.png
# [Fold 7] Test Loss: 0.9317, Test Acc: 0.6683
# Saved model for fold 7 to: /kaggle/working/model-b/vgg13_b_fold7.pth
# ================================================================================
# Fold 8 as TEST fold
# ================================================================================
# Train folds: [1, 2, 3, 4, 5, 6, 7, 9]
# Val fold:   10
# Test fold:  8
#
# Switch to stage 1 at epoch 1, lr = 1e-05
#
# [Fold 8] Epoch 1/10 (Stage 1, lr=1e-05)
# Train Loss: 1.9894, Train Acc: 0.3209
# Val   Loss: 1.5633, Val   Acc: 0.6105
#
# [Fold 8] Epoch 2/10 (Stage 1, lr=1e-05)
# Train Loss: 1.3518, Train Acc: 0.5744
# Val   Loss: 1.1189, Val   Acc: 0.6774
#
# [Fold 8] Epoch 3/10 (Stage 1, lr=1e-05)
# Train Loss: 1.0397, Train Acc: 0.6727
# Val   Loss: 0.9656, Val   Acc: 0.7037
#
# [Fold 8] Epoch 4/10 (Stage 1, lr=1e-05)
# Train Loss: 0.8488, Train Acc: 0.7289
# Val   Loss: 0.8770, Val   Acc: 0.7336
#
# [Fold 8] Epoch 5/10 (Stage 1, lr=1e-05)
# Train Loss: 0.7326, Train Acc: 0.7735
# Val   Loss: 0.8349, Val   Acc: 0.7324
#
# [Fold 8] Epoch 6/10 (Stage 1, lr=1e-05)
# Train Loss: 0.6514, Train Acc: 0.7966
# Val   Loss: 0.7994, Val   Acc: 0.7372
#
# [Fold 8] Epoch 7/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5743, Train Acc: 0.8211
# Val   Loss: 0.7956, Val   Acc: 0.7539
#
# [Fold 8] Epoch 8/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5116, Train Acc: 0.8455
# Val   Loss: 0.7774, Val   Acc: 0.7599
#
# [Fold 8] Epoch 9/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4522, Train Acc: 0.8603
# Val   Loss: 0.7878, Val   Acc: 0.7599
#
# [Fold 8] Epoch 10/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4167, Train Acc: 0.8740
# Val   Loss: 0.7846, Val   Acc: 0.7634
# Saved learning curve to: /kaggle/working/model-b/vgg13_b_fold8_curve.png
# [Fold 8] Test Loss: 0.9926, Test Acc: 0.6898
# Saved model for fold 8 to: /kaggle/working/model-b/vgg13_b_fold8.pth
# ================================================================================
# Fold 9 as TEST fold
# ================================================================================
# Train folds: [1, 2, 3, 4, 5, 6, 7, 8]
# Val fold:   10
# Test fold:  9
#
# Switch to stage 1 at epoch 1, lr = 1e-05
#
# [Fold 9] Epoch 1/10 (Stage 1, lr=1e-05)
# Train Loss: 2.0388, Train Acc: 0.2999
# Val   Loss: 1.5916, Val   Acc: 0.5866
#
# [Fold 9] Epoch 2/10 (Stage 1, lr=1e-05)
# Train Loss: 1.3941, Train Acc: 0.5525
# Val   Loss: 1.1202, Val   Acc: 0.6631
#
# [Fold 9] Epoch 3/10 (Stage 1, lr=1e-05)
# Train Loss: 1.0414, Train Acc: 0.6669
# Val   Loss: 0.9516, Val   Acc: 0.6930
#
# [Fold 9] Epoch 4/10 (Stage 1, lr=1e-05)
# Train Loss: 0.8576, Train Acc: 0.7284
# Val   Loss: 0.8804, Val   Acc: 0.7109
#
# [Fold 9] Epoch 5/10 (Stage 1, lr=1e-05)
# Train Loss: 0.7443, Train Acc: 0.7621
# Val   Loss: 0.8256, Val   Acc: 0.7419
#
# [Fold 9] Epoch 6/10 (Stage 1, lr=1e-05)
# Train Loss: 0.6445, Train Acc: 0.7945
# Val   Loss: 0.7921, Val   Acc: 0.7539
#
# [Fold 9] Epoch 7/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5681, Train Acc: 0.8227
# Val   Loss: 0.7936, Val   Acc: 0.7455
#
# [Fold 9] Epoch 8/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5184, Train Acc: 0.8401
# Val   Loss: 0.7538, Val   Acc: 0.7599
#
# [Fold 9] Epoch 9/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4710, Train Acc: 0.8572
# Val   Loss: 0.7463, Val   Acc: 0.7611
#
# [Fold 9] Epoch 10/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4148, Train Acc: 0.8739
# Val   Loss: 0.7455, Val   Acc: 0.7670
# Saved learning curve to: /kaggle/working/model-b/vgg13_b_fold9_curve.png
# [Fold 9] Test Loss: 0.8516, Test Acc: 0.7806
# Saved model for fold 9 to: /kaggle/working/model-b/vgg13_b_fold9.pth
# ================================================================================
# Fold 10 as TEST fold
# ================================================================================
# Train folds: [1, 2, 3, 4, 5, 6, 7, 8]
# Val fold:   9
# Test fold:  10
#
# Switch to stage 1 at epoch 1, lr = 1e-05
#
# [Fold 10] Epoch 1/10 (Stage 1, lr=1e-05)
# Train Loss: 2.0421, Train Acc: 0.2913
# Val   Loss: 1.6612, Val   Acc: 0.5135
#
# [Fold 10] Epoch 2/10 (Stage 1, lr=1e-05)
# Train Loss: 1.4066, Train Acc: 0.5680
# Val   Loss: 1.1887, Val   Acc: 0.6238
#
# [Fold 10] Epoch 3/10 (Stage 1, lr=1e-05)
# Train Loss: 1.0595, Train Acc: 0.6649
# Val   Loss: 1.0363, Val   Acc: 0.6752
#
# [Fold 10] Epoch 4/10 (Stage 1, lr=1e-05)
# Train Loss: 0.8801, Train Acc: 0.7156
# Val   Loss: 0.9516, Val   Acc: 0.7132
#
# [Fold 10] Epoch 5/10 (Stage 1, lr=1e-05)
# Train Loss: 0.7631, Train Acc: 0.7624
# Val   Loss: 0.9203, Val   Acc: 0.7267
#
# [Fold 10] Epoch 6/10 (Stage 1, lr=1e-05)
# Train Loss: 0.6622, Train Acc: 0.7923
# Val   Loss: 0.8924, Val   Acc: 0.7145
#
# [Fold 10] Epoch 7/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5909, Train Acc: 0.8130
# Val   Loss: 0.8737, Val   Acc: 0.7439
#
# [Fold 10] Epoch 8/10 (Stage 1, lr=1e-05)
# Train Loss: 0.5321, Train Acc: 0.8343
# Val   Loss: 0.8611, Val   Acc: 0.7463
#
# [Fold 10] Epoch 9/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4688, Train Acc: 0.8570
# Val   Loss: 0.8686, Val   Acc: 0.7451
#
# [Fold 10] Epoch 10/10 (Stage 1, lr=1e-05)
# Train Loss: 0.4269, Train Acc: 0.8698
# Val   Loss: 0.8411, Val   Acc: 0.7574
# Saved learning curve to: /kaggle/working/model-b/vgg13_b_fold10_curve.png
# [Fold 10] Test Loss: 0.7720, Test Acc: 0.7587
# Saved model for fold 10 to: /kaggle/working/model-b/vgg13_b_fold10.pth
